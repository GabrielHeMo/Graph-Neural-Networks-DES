# %% [markdown]
# # GNN with explicit inter-molecular interactions

# %%
# Utilities
from tqdm.notebook import tqdm
# Scientific python
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams['font.size'] = 10
plt.rcParams['axes.axisbelow'] = True
plt.rcParams['figure.figsize'] = [7, 5]
plt.rcParams["text.usetex"] = False
import sklearn
from sklearn.metrics import r2_score , mean_absolute_error , mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler

# Pytorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric
import torch_geometric.nn as gnn
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch.utils.data import Subset
from torch_geometric.nn.pool import global_add_pool
from torch.utils.data import TensorDataset
from torch_geometric.utils import scatter
from torch_geometric.data import Batch
from torch.utils.data import Dataset
import random
# RDKit
import rdkit
from rdkit import Chem
import mordred
from mordred.Polarizability import APol, BPol
from mordred.TopoPSA import TopoPSA
from rdkit.Chem import rdMolDescriptors
print('Pytorch version:',torch.__version__)
print('Pytorch Geometric version:',torch_geometric.__version__)
print('RDKit version:', rdkit.__version__)
print('Mordred version:', mordred.__version__)
tqdm.pandas()
# Out:
# Pytorch version: 2.2.1+cpu
# Pytorch Geometric version: 2.5.0
# RDKit version: 2023.09.5
# Mordred version: 1.2.0

# %%
# random seed for Python's random module
seed = 42
random.seed(seed)

# random seed for NumPy
np.random.seed(seed)

# random seed for PyTorch
torch.manual_seed(seed)

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('data_cleaned_sol.csv')

# %% [markdown]
# ## Add SMILES

# %%
df_hba = pd.read_csv('HBA_smiles_sol.csv')
df_hbd = pd.read_csv('HBD_smiles_sol.csv')

# %%
df['HBA_SMILES'] = df['HBA name'].map(df_hba.set_index('Short')['SMILES'])
df['HBD_SMILES'] = df['HBD name'].map(df_hbd.set_index('Short')['SMILES'])

# %% [markdown]
# ## Create molecules

# %%
df['mol_hba'] = df['HBA_SMILES'].apply(Chem.MolFromSmiles)
df['mol_hbd'] = df['HBD_SMILES'].apply(Chem.MolFromSmiles)

# %% [markdown]
# ## Compute molecular descriptors

# %% [markdown]
# ### Atomic polarizability

# %%
ap_fun = APol()
df['ap_hba'] = df['mol_hba'].apply(ap_fun)
df['ap_hbd'] = df['mol_hbd'].apply(ap_fun)

# %% [markdown]
# ### Bond polarizability

# %%
bp_fun = BPol()
df['bp_hba'] = df['mol_hba'].apply(bp_fun)
df['bp_hbd'] = df['mol_hbd'].apply(bp_fun)

# %% [markdown]
# ### Topological polar surface area

# %%
topopsa_fun = TopoPSA()
df['topopsa_hba'] = df['mol_hba'].apply(topopsa_fun)
df['topopsa_hbd'] = df['mol_hbd'].apply(topopsa_fun)

# %% [markdown]
# ### Intra-molecular hydrogen-bonding sites

# %%
def get_hb_sites(mol):
  return min(rdMolDescriptors.CalcNumHBA(mol), rdMolDescriptors.CalcNumHBD(mol))

df['hb_hba'] = df['mol_hba'].apply(get_hb_sites)
df['hb_hbd'] = df['mol_hbd'].apply(get_hb_sites)

# %% [markdown]
# ### Inter-molecular hydrogen bonding sites

# %%
def get_inter_hb_sites(row):
    mol1 = row['mol_hba']
    mol2 = row['mol_hbd']
    return min(rdMolDescriptors.CalcNumHBA(mol1), rdMolDescriptors.CalcNumHBD(mol2)) + \
           min(rdMolDescriptors.CalcNumHBA(mol2), rdMolDescriptors.CalcNumHBD(mol1))


df['inter_hb'] = df.apply(get_inter_hb_sites, axis=1)

# %% [markdown]
# ## Normalize data

# %%
train_df = df[df['Split'] == 'Training'].copy()
test_df = df[df['Split'] == 'Testing'].copy()

# Extract features and target
features = ['T (K)', 'P (kPa)', 'r HBA', 'r HBD', 'ap_hba', 'ap_hbd', 'bp_hba',
            'bp_hbd', 'topopsa_hba', 'topopsa_hbd', 'hb_hba', 'hb_hbd', 'inter_hb']
X_train = train_df[features].values
y_train = train_df['ln(x)-experimental'].values
X_test = test_df[features].values
y_test = test_df['ln(x)-experimental'].values

# Normalize the features
scaler = StandardScaler()
X_train_norm = scaler.fit_transform(X_train)
X_test_norm = scaler.transform(X_test)

# Add normalized features back to the original DataFrame
norm_feature_names = ['T_norm', 'P_norm', 'r_HBA_norm', 'r_HBD_norm', 'ap_hba_norm', 'ap_hbd_norm', 'bp_hba_norm',
            'bp_hbd_norm', 'topopsa_hba_norm', 'topopsa_hbd_norm', 'hb_hba_norm', 'hb_hbd_norm', 'inter_hb_norm']
train_df[norm_feature_names] = X_train_norm
test_df[norm_feature_names] = X_test_norm

# Combine the training and testing dataframes
df = pd.concat([train_df, test_df])

# to preserve the original order
df = df.sort_index()

# Save standar scaler 
import joblib
joblib.dump(scaler, 'std_scaler_sol.bin', compress=True)
# Out:
# ['std_scaler_sol.bin']

# %%
df
# Out:
#                                      DES   T (K)  P (kPa)       S1        S2  \
# 0         [Ach]Cl-1,2,4-triazole (1 : 1)  303.15     63.7  0.02290  0.369525
# 1         [Ach]Cl-1,2,4-triazole (1 : 1)  303.15    107.6  0.02290  0.369525
# 2         [Ach]Cl-1,2,4-triazole (1 : 1)  303.15    192.5  0.02290  0.369525
# 3         [Ach]Cl-1,2,4-triazole (1 : 1)  303.15    288.3  0.02290  0.369525
# 4         [Ach]Cl-1,2,4-triazole (1 : 1)  303.15    382.9  0.02290  0.369525
# ...                                  ...     ...      ...      ...       ...
# 1968  [Ch]Cl-ethylenecyanohydrin (1 : 3)  328.15    112.5  0.00165  0.247350
# 1969  [Ch]Cl-ethylenecyanohydrin (1 : 3)  328.15    421.4  0.00165  0.247350
# 1970  [Ch]Cl-ethylenecyanohydrin (1 : 3)  328.15    816.0  0.00165  0.247350
# 1971  [Ch]Cl-ethylenecyanohydrin (1 : 3)  328.15   1138.5  0.00165  0.247350
# 1972  [Ch]Cl-ethylenecyanohydrin (1 : 3)  328.15   1405.7  0.00165  0.247350
#
#             S3        S4       S5        S6        S7  ...  r_HBD_norm  \
# 0     1.369675  4.434675  3.93895  1.367150  0.953500  ...   -1.352371
# 1     1.369675  4.434675  3.93895  1.367150  0.953500  ...   -1.352371
# 2     1.369675  4.434675  3.93895  1.367150  0.953500  ...   -1.352371
# 3     1.369675  4.434675  3.93895  1.367150  0.953500  ...   -1.352371
# 4     1.369675  4.434675  3.93895  1.367150  0.953500  ...   -1.352371
# ...        ...       ...      ...       ...       ...  ...         ...
# 1968  0.952237  4.327763  2.18630  1.027637  1.334837  ...   -0.214471
# 1969  0.952237  4.327763  2.18630  1.027637  1.334837  ...   -0.214471
# 1970  0.952237  4.327763  2.18630  1.027637  1.334837  ...   -0.214471
# 1971  0.952237  4.327763  2.18630  1.027637  1.334837  ...   -0.214471
# 1972  0.952237  4.327763  2.18630  1.027637  1.334837  ...   -0.214471
#
#       ap_hba_norm  ap_hbd_norm  bp_hba_norm bp_hbd_norm  topopsa_hba_norm  \
# 0       -0.342211    -1.197903    -0.244402   -1.186061          0.887977
# 1       -0.342211    -1.197903    -0.244402   -1.186061          0.887977
# 2       -0.342211    -1.197903    -0.244402   -1.186061          0.887977
# 3       -0.342211    -1.197903    -0.244402   -1.186061          0.887977
# 4       -0.342211    -1.197903    -0.244402   -1.186061          0.887977
# ...           ...          ...          ...         ...               ...
# 1968    -0.608257    -0.929740    -0.583881   -0.984723          0.435882
# 1969    -0.608257    -0.929740    -0.583881   -0.984723          0.435882
# 1970    -0.608257    -0.929740    -0.583881   -0.984723          0.435882
# 1971    -0.608257    -0.929740    -0.583881   -0.984723          0.435882
# 1972    -0.608257    -0.929740    -0.583881   -0.984723          0.435882
#
#      topopsa_hbd_norm  hb_hba_norm  hb_hbd_norm inter_hb_norm
# 0           -0.003074    -0.773265    -0.799158     -0.053547
# 1           -0.003074    -0.773265    -0.799158     -0.053547
# 2           -0.003074    -0.773265    -0.799158     -0.053547
# 3           -0.003074    -0.773265    -0.799158     -0.053547
# 4           -0.003074    -0.773265    -0.799158     -0.053547
# ...               ...          ...          ...           ...
# 1968         0.206649     1.293218    -0.799158      1.022355
# 1969         0.206649     1.293218    -0.799158      1.022355
# 1970         0.206649     1.293218    -0.799158      1.022355
# 1971         0.206649     1.293218    -0.799158      1.022355
# 1972         0.206649     1.293218    -0.799158      1.022355
#
# [1973 rows x 48 columns]

# %% [markdown]
# ## Create graphs

# %%
def one_of_k_encoding(x, allowable_set):
    if x not in allowable_set:
        raise Exception("input {0} not in allowable set{1}:".format(
            x, allowable_set))
    return list(map(lambda s: x == s, allowable_set))

# %% [markdown]
# ### Atomic features

# %%
possible_atom_list = [
    'C',
    'O',
    'N',
    'Cl',
    'Br',
    'P',
    ]
possible_hybridization = [
    Chem.rdchem.HybridizationType.SP,
    Chem.rdchem.HybridizationType.SP2,
    Chem.rdchem.HybridizationType.SP3
    ]
possible_num_bonds = [
    0,
    1,
    2,
    3,
    4
    ]
possible_formal_charge = [
    0,
    1,
    -1
    ]
possible_num_Hs  = [
    0,
    1,
    2,
    3
    ]

def atom_features(atom):
    '''
    Get atom features
    '''
    Symbol       = atom.GetSymbol()
    Type_atom     = one_of_k_encoding(Symbol, possible_atom_list)
    Ring_atom     = [atom.IsInRing()]
    Aromaticity   = [atom.GetIsAromatic()]
    Hybridization = one_of_k_encoding(atom.GetHybridization(), possible_hybridization)
    Bonds_atom    = one_of_k_encoding(len(atom.GetNeighbors()), possible_num_bonds)
    Formal_charge = one_of_k_encoding(atom.GetFormalCharge(), possible_formal_charge)
    num_Hs        = one_of_k_encoding(atom.GetTotalNumHs(), possible_num_Hs)

    results = Type_atom + Ring_atom + Aromaticity + Hybridization + Bonds_atom +  \
      Formal_charge + num_Hs
    return np.array(results).astype(np.float32)

# %% [markdown]
# ### Bond features

# %%
def get_bond_pair(mol):
    bonds = mol.GetBonds()
    res = [[], []]
    for bond in bonds:
        res[0] += [bond.GetBeginAtomIdx(), bond.GetEndAtomIdx()]
        res[1] += [bond.GetEndAtomIdx(), bond.GetBeginAtomIdx()]
    return res

def bond_features(bond):
    bt = bond.GetBondType()
    # Features
    bond_feats = [
        bt == Chem.rdchem.BondType.SINGLE, bt == Chem.rdchem.BondType.DOUBLE,
        bt == Chem.rdchem.BondType.TRIPLE, bt == Chem.rdchem.BondType.AROMATIC,
        bond.GetIsConjugated(),
        bond.IsInRing()]
    return np.array(bond_feats).astype(np.float32)

# %% [markdown]
# ## Utilities

# %%
def n_atom_features():
    atom = Chem.MolFromSmiles('CC').GetAtomWithIdx(0)
    return len(atom_features(atom))

def n_bond_features():
    bond = Chem.MolFromSmiles('CC').GetBondWithIdx(0)
    return len(bond_features(bond))

def sys2graph(df, mol_column_1, mol_column_2, target, single_system=False):
    """
    Constructs graph representations of binary molecular systems.

    Parameters:
    df (pd.DataFrame): Input dataframe.
    mol_column_1 (str): Column name for the first component.
    mol_column_2 (str): Column name for the second component.
    target (str): Column name for the target variable.
    single_system (bool, optional): Whether to treat the dataframe as a single system.

    Returns:
    list: A list of graph objects.
    """
    def process_component(comp):
        """Processes a single component to extract edge attributes and indices."""
        edge_attr = []
        edge_index = get_bond_pair(comp)
        for bond in comp.GetBonds():
            edge_attr.extend([bond_features(bond)] * 2)
        return edge_attr, edge_index

    def info2graph(node_feat, edge_indx, edge_attr, y):
        """Creates graph for a component including the intra- and inter-molecular information"""
        nodes_info = torch.tensor(np.array(node_feat), dtype=torch.float32)
        edges_indx = torch.tensor(np.array(edge_indx), dtype=torch.long)
        edges_info = torch.tensor(np.array(edge_attr), dtype=torch.float32)
        graph = Data(x=nodes_info, edge_index=edges_indx, edge_attr=edges_info)
        graph.y = torch.tensor(y, dtype=torch.float)
        return graph

    def create_graph_indiv(c1, c2, y_val):
        """Helper function to create individual graphs."""
        atoms_c1 = c1.GetAtoms()
        atoms_c2 = c2.GetAtoms()
        node_features_c1 = [atom_features(atom) for atom in atoms_c1]
        node_features_c2 = [atom_features(atom) for atom in atoms_c2]

        edge_attr_c1, edge_index_c1 = process_component(c1)
        edge_attr_c2, edge_index_c2 = process_component(c2)

        # Info to graphs
        graph_c1 = info2graph(node_features_c1, edge_index_c1, edge_attr_c1, y_val)
        graph_c2 = info2graph(node_features_c2, edge_index_c2, edge_attr_c2, y_val)

        return graph_c1, graph_c2

    def create_graphs_from_row(row, mol_column_1, mol_column_2, target):
        graph_c1, graph_c2 = create_graph_indiv(row[mol_column_1], row[mol_column_2], row[target])

        # Append extra information to the graphs
        for graph in [graph_c1, graph_c2]:
            graph.Temp = row['T_norm']
            graph.P = row['P_norm']
            graph.mol_x = row['r_HBA_norm'] if graph == graph_c1 else row['r_HBD_norm']
            graph.ap = row['ap_hba_norm'] if graph == graph_c1 else row['ap_hbd_norm']
            graph.bp = row['bp_hba_norm'] if graph == graph_c1 else row['bp_hbd_norm']
            graph.topopsa = row['topopsa_hba_norm'] if graph == graph_c1 else row['topopsa_hbd_norm']
            graph.hb = row['hb_hba_norm'] if graph == graph_c1 else row['hb_hbd_norm']
            graph.inter_hb = row['inter_hb_norm']

        return graph_c1, graph_c2

    # Main function logic
    graphs_c1, graphs_c2 = zip(*df.apply(create_graphs_from_row, axis=1, args=(mol_column_1, mol_column_2, target)))
    return graphs_c1, graphs_c2

# %%
g_hba_lst, g_hbd_lst = sys2graph(df, 'mol_hba', 'mol_hbd', 'ln(x)-experimental')
df['g_hba'] = g_hba_lst
df['g_hbd'] = g_hbd_lst

# %% [markdown]
# ## Graph Neural Network

# %%
class MPNNconv(nn.Module):
    def __init__(self, node_in_feats, edge_in_feats, node_out_feats,
                 edge_hidden_feats=32, num_step_message_passing=1):
        super(MPNNconv, self).__init__()

        self.project_node_feats = nn.Sequential(
            nn.Linear(node_in_feats, node_out_feats),
            nn.ReLU()
        )

        self.num_step_message_passing = num_step_message_passing

        edge_network = nn.Sequential(
            nn.Linear(edge_in_feats, edge_hidden_feats),
            nn.ReLU(),
            nn.Linear(edge_hidden_feats, node_out_feats*node_out_feats)
        )
        self.gnn_layer = gnn.NNConv(
            node_out_feats,
            node_out_feats,
            edge_network,
            aggr='add'
        )
        self.gru = nn.GRU(node_out_feats, node_out_feats)

    def reset_parameters(self):
        self.project_node_feats[0].reset_parameters()
        self.gnn_layer.reset_parameters()
        for layer in self.gnn_layer.edge_func:
            if isinstance(layer, nn.Linear):
                layer.reset_parameters()
        self.gru.reset_parameters()

    def forward(self, system_graph):

        node_feats = system_graph.x
        edge_index = system_graph.edge_index
        edge_feats = system_graph.edge_attr
        node_feats = self.project_node_feats(node_feats) # (V, node_out_feats)
        hidden_feats = node_feats.unsqueeze(0)           # (1, V, node_out_feats)

        for _ in range(self.num_step_message_passing):
            if torch.cuda.is_available():
                node_feats = F.relu(self.gnn_layer(x=node_feats.type(torch.FloatTensor).cuda(),
                                                   edge_index=edge_index.type(torch.LongTensor).cuda(),
                                                   edge_attr=edge_feats.type(torch.FloatTensor).cuda()))
            else:
                node_feats = F.relu(self.gnn_layer(x=node_feats.type(torch.FloatTensor),
                                                   edge_index=edge_index.type(torch.LongTensor),
                                                   edge_attr=edge_feats.type(torch.FloatTensor)))
            node_feats, hidden_feats = self.gru(node_feats.unsqueeze(0), hidden_feats)
            node_feats = node_feats.squeeze(0)
        return node_feats

class EdgeModel(torch.nn.Module):
    def __init__(self, v_in, e_in, u_in, hidden_dim):
        super().__init__()

        layers = [nn.Linear(v_in*2 + e_in + u_in, hidden_dim),
                  nn.ReLU(),
                  nn.Linear(hidden_dim, hidden_dim)]

        self.edge_mlp = nn.Sequential(*layers)

    def forward(self, src, dest, edge_attr, u, batch):
        out = torch.cat([src, dest, edge_attr, u[batch]], axis=1)
        return self.edge_mlp(out)

class NodeModel(torch.nn.Module):
    def __init__(self, v_in, u_in, hidden_dim):
        super().__init__()

        layers = [nn.Linear(v_in + hidden_dim + u_in, hidden_dim),
                  nn.ReLU(),
                  nn.Linear(hidden_dim, hidden_dim)]

        self.node_mlp = nn.Sequential(*layers)

    def forward(self, x, edge_index, edge_attr, u, batch):
        row, col = edge_index
        out = scatter(edge_attr, col, dim=0, dim_size=x.size(0), reduce='sum')
        out = torch.cat([x, out, u[batch]], dim=1)
        return self.node_mlp(out)

class GlobalModel(torch.nn.Module):
    def __init__(self, u_in, hidden_dim):
        super().__init__()

        layers = [nn.Linear(hidden_dim + hidden_dim + u_in, hidden_dim),
                  nn.ReLU(),
                  nn.Linear(hidden_dim, hidden_dim)]

        self.global_mlp = nn.Sequential(*layers)

    def forward(self, x, edge_index, edge_attr, u, batch):
        node_aggregate = scatter(x, batch, dim=0, reduce='sum')
        edge_aggregate = scatter(edge_attr, batch[edge_index[1]], dim=0, reduce='sum')
        out = torch.cat([u, node_aggregate, edge_aggregate], dim=1)
        return self.global_mlp(out)

class GHGNN(nn.Module):
    def __init__(self, v_in, e_in, u_in, hidden_dim, n_extra_inputs):
        super(GHGNN, self).__init__()
        self.graphnet1 = gnn.MetaLayer(EdgeModel(v_in, e_in, u_in, hidden_dim),
                                      NodeModel(v_in, u_in, hidden_dim),
                                      GlobalModel(u_in, hidden_dim))
        self.graphnet2 = gnn.MetaLayer(EdgeModel(hidden_dim, hidden_dim, hidden_dim, hidden_dim),
                                      NodeModel(hidden_dim, hidden_dim, hidden_dim),
                                      GlobalModel(hidden_dim, hidden_dim))

        self.gnorm1 = gnn.GraphNorm(hidden_dim)
        self.gnorm2 = gnn.GraphNorm(hidden_dim)

        self.pool = global_add_pool

        self.global_conv1 = MPNNconv(node_in_feats=hidden_dim*2,
                                     edge_in_feats=1,
                                     node_out_feats=hidden_dim*2)

        # MLP
        self.mlp1 = nn.Linear(hidden_dim*4 + n_extra_inputs, hidden_dim)
        self.mlp2 = nn.Linear(hidden_dim, hidden_dim)
        self.mlp3 = nn.Linear(hidden_dim, 1)

    def generate_sys_graph(self, x, edge_attr, batch_size, n_mols=2):

        src = np.arange(batch_size)
        dst = np.arange(batch_size, n_mols*batch_size)

        self_connection = np.arange(n_mols*batch_size)

        # Biderectional connections (between each molecule in the system)
        # and self-connection
        one_way = np.concatenate((src, dst, self_connection))
        other_way = np.concatenate((dst, src, self_connection))
        edge_index = torch.tensor([list(one_way),
                                   list(other_way)], dtype=torch.long)
        sys_graph = Data(x=x, edge_index=edge_index, edge_attr=edge_attr)
        return sys_graph

    def forward(self, c1, c2):
        # ---- Atomic polarizability
        ap1 = c1.ap.reshape(-1,1)
        ap2 = c2.ap.reshape(-1,1)

        # ---- Bond polarizability
        bp1 = c1.bp.reshape(-1,1)
        bp2 = c2.bp.reshape(-1,1)

        # -- Polarity via topological polar surface area
        topopsa1 = c1.topopsa.reshape(-1,1)
        topopsa2 = c2.topopsa.reshape(-1,1)

        # -- Hydrogen-bond acidity and basicity
        intra_hb1 = c1.inter_hb
        intra_hb2 = c2.inter_hb

        u1 = torch.cat((ap1,bp1,topopsa1), axis=1) # Molecular descriptors molecule 1
        u2 = torch.cat((ap2,bp2,topopsa2), axis=1) # Molecular descriptors molecule 2

        # Molecule 1 GraphNet
        x1, edge_attr1, u1 = self.graphnet1(c1.x, c1.edge_index, c1.edge_attr, u1, c1.batch)
        x1 = self.gnorm1(x1, c1.batch)
        x1, edge_attr1, u1 = self.graphnet2(x1, c1.edge_index, edge_attr1, u1, c1.batch)
        x1 = self.gnorm2(x1, c1.batch)
        xg1 = self.pool(x1, c1.batch)

        # Molecule 2 GraphNet
        x2, edge_attr2, u2 = self.graphnet1(c2.x, c2.edge_index, c2.edge_attr, u2, c2.batch)
        x2 = self.gnorm1(x2, c2.batch)
        x2, edge_attr2, u2 = self.graphnet2(x2, c2.edge_index, edge_attr2, u2, c2.batch)
        x2 = self.gnorm2(x2, c2.batch)
        xg2 = self.pool(x2, c2.batch)

        batch_size = c1.y.shape[0]

        # Intermolecular descriptors
        # -- Hydrogen bonding
        inter_hb  = c1.inter_hb
        # Construct binary system graph
        node_feat = torch.cat((
            torch.cat((xg1, u1), axis=1),
            torch.cat((xg2, u2), axis=1)),axis=0)
        edge_feat = torch.cat((inter_hb.repeat(2),
                               intra_hb1,
                               intra_hb2)).unsqueeze(1)
        binary_sys_graph = self.generate_sys_graph(x=node_feat,
                                                   edge_attr=edge_feat,
                                                   batch_size=batch_size)
        xg = self.global_conv1(binary_sys_graph)


        xg = torch.cat((xg[0:len(xg)//2,:], xg[len(xg)//2:,:]), axis=1)

        T = torch.reshape(c1.Temp,(-1,1))
        P = torch.reshape(c2.P,(-1,1))
        x1 = torch.reshape(c1.mol_x,(-1,1))
        x2 = torch.reshape(c2.mol_x,(-1,1))

        ExtraVar = torch.cat((T,P,x1,x2),1)
        x = torch.cat((xg,ExtraVar),1)
        x = F.sigmoid(self.mlp1(x))
        x = F.sigmoid(self.mlp2(x))
        x = self.mlp3(x)
        return x

class AccumulationMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.value = 0.0
        self.sum = 0.0
        self.count = 0.0
        self.avg = 0.0

    def update(self, value, n=1):
        self.value = value
        self.sum += value * n
        self.count += n
        self.avg = self.sum / self.count

# %%
class PairDataset(Dataset):
    def __init__(self, datasetA, datasetB):
        self.datasetA = datasetA
        self.datasetB = datasetB
    def __getitem__(self, idx):
        return self.datasetA[idx], self.datasetB[idx]
    def __len__(self):
        return len(self.datasetA)

def collate(data_list):
    batchA = Batch.from_data_list([data[0] for data in data_list])
    batchB = Batch.from_data_list([data[1] for data in data_list])
    return batchA, batchB

def get_dataloader_pairs(df, graphs_c1, graphs_c2, batch_size, shuffle=False, drop_last=False):

    g1s = df[graphs_c1].tolist()
    g2s  = df[graphs_c2].tolist()

    pair_dataset = PairDataset(g1s, g2s)
    data_loader  = torch.utils.data.DataLoader(pair_dataset, batch_size=batch_size, shuffle=shuffle, drop_last=drop_last, collate_fn=collate)

    return data_loader

# %%
train_df = df[df['Split'] == 'Training']
test_df = df[df['Split'] == 'Testing']

train_dataloader = get_dataloader_pairs(train_df, 'g_hba', 'g_hbd', batch_size=32, shuffle=False, drop_last=False)
test_dataloader = get_dataloader_pairs(test_df, 'g_hba', 'g_hbd', batch_size=32, shuffle=False, drop_last=False)

# %%
def train(model, device, dataloader, optimizer, loss_fn):
    """
    Trains the model.

    Parameters:
    model: The neural network model to train.
    device: The device (CPU or CUDA) to use for training.
    dataloader: DataLoader object for the training data.
    optimizer: Optimizer for the training process.
    loss_fn: Loss function used for training.

    Returns:
    Average loss over the training dataset.
    """
    model.train()
    loss_accum = AccumulationMeter()
    for batch_c1, batch_c2 in dataloader:
        y =  batch_c1.y
        X1 = batch_c1
        X2 = batch_c2
        X1, X2, y = X1.to(device), X2.to(device), y.to(device)

        # Model prediction and loss calculation
        y_hat = model(X1, X2)
        loss = loss_fn(y_hat, y.reshape(-1,1))
        loss_accum.update(loss.item(), y.size(0))

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    return loss_accum.avg

def test(model, device, dataloader, loss_fn):
    """
    Evaluates the model's performance on a test dataset.

    Parameters:
    model: The neural network model to evaluate.
    device: The device (CPU or CUDA) to use for evaluation.
    dataloader: DataLoader object for the test data.
    loss_fn: Loss function used for evaluation.

    Returns:
    Average loss over the test dataset.
    """
    model.eval()  # Set the model to evaluation mode
    loss_accum = AccumulationMeter()
    with torch.no_grad():  # Disable gradient computation
        for batch_c1, batch_c2 in dataloader:
            y =  batch_c1.y
            X1 = batch_c1
            X2 = batch_c2
            X1, X2, y = X1.to(device), X2.to(device), y.to(device)

            # Model prediction and loss calculation
            y_hat = model(X1, X2)
            loss = loss_fn(y_hat, y.reshape(-1,1))
            loss_accum.update(loss.item(), y.size(0))

    return loss_accum.avg

# %%
def parity_plots(y_train, y_train_hat, y_test, y_test_hat):

  metrics = [r2_score, mean_absolute_percentage_error, mean_absolute_error, mean_squared_error]
  metric_names = ['R2', 'MAPE', 'MAE', 'RMSE']

  metrics_dict = {}
  for split, (y_true, y_pred) in zip(['train', 'test'], [(y_train, y_train_hat), (y_test, y_test_hat)]):
    metrics_dict[split] = {}
    for name, metric in zip(metric_names, metrics):
      metrics_dict[split][name] = metric(y_true, y_pred)

  metrics_train = (r'$R^2 = {:.2f} $' '\n' r'$AARD = {:.2f}$ %' '\n' r'$MAE = {:.2f}$' '\n' r'$RMSE = {:.2f}$' .format(
      metrics_dict['train']['R2'],
      metrics_dict['train']['MAPE']*100,
      metrics_dict['train']['MAE'],
      metrics_dict['train']['RMSE']**0.5))

  metrics_test = (r'$R^2 = {:.2f} $' '\n' r'$AARD = {:.2f}$ %' '\n' r'$MAE = {:.2f}$' '\n' r'$RMSE = {:.2f}$' .format(
      metrics_dict['test']['R2'],
      metrics_dict['test']['MAPE']*100,
      metrics_dict['test']['MAE'],
      metrics_dict['test']['RMSE']**0.5))

  fig , (ax1,ax2) = plt.subplots(1,2, figsize=(10.0 ,5.0))

  ax1.set_xlabel(r'$ln(x^{exp}_{CO_2}) $')
  ax1.set_ylabel(r'$ln(x^{pred}_{CO_2}) $')
  ax1.set_ylim([-7.5,-0.5])
  ax1.set_xlim([-7.5,-0.5])
  ax1.text(-6.8,-2.5, metrics_train, fontsize=10)
  ax1.grid(visible=True,which='major',linestyle = '--' ,linewidth = 0.5)
  ax1.scatter(y_train, y_train_hat, label='Training', marker='s', color='red')
  ax1.plot(np.linspace(-7,-1), np.linspace(-7,-1),linestyle = '--' , color  = 'black')
  ax1.legend(loc="best")

  ax2.set_xlabel(r'$ln(x^{exp}_{CO_2}) $')
  ax2.set_ylabel(r'$ln(x^{pred}_{CO_2}) $')
  ax2.set_ylim([-7.5,-0.5])
  ax2.set_xlim([-7.5,-0.5])
  ax2.text(-6.8,-2.5, metrics_test, fontsize=10)
  ax2.grid(visible=True,which='major', linestyle = '--' ,linewidth = 0.5)
  ax2.scatter(y_test, y_test_hat, label='Testing', marker='s', color='blue')
  ax2.plot(np.linspace(-7,-1),np.linspace(-7,-1),linestyle = '--' , color  = 'black')
  ax2.legend(loc="best")

# %% [markdown]
# ### Training with tuned hyperparameterts

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = GHGNN(n_atom_features(), n_bond_features(), 3, 25, 4).to(device)

loss_fn = nn.MSELoss(reduction='mean')
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0006031500598155615)
epochs = 1000

# %%
train_loss_save, test_loss_save = [], []
pbar = tqdm(range(epochs))
for epoch in pbar:
    train_loss = train(model, device, train_dataloader, optimizer, loss_fn)
    train_loss_save.append(train_loss)
    test_loss = test(model,device,test_dataloader,loss_fn)
    test_loss_save.append(test_loss)

    pbar.set_postfix(train_loss=train_loss)

torch.save({
    'epoch': epoch + 1,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    },
           'GNN_MG.pth')
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
train_mse = np.sqrt(np.array(train_loss_save))
test_mse = np.sqrt(np.array(test_loss_save))
plt.plot(train_mse,label="Train RMSE")
plt.plot(test_mse,label="Test RMSE")
plt.xlabel("epoch")
plt.ylabel("RMSE")
plt.legend(loc="best")
plt.yscale('log')

# %%
model = GHGNN(n_atom_features(), n_bond_features(), 3, 25, 4).to(device)
checkpoint = torch.load('GNN_MG.pth')
model.load_state_dict(checkpoint['model_state_dict'])

y_hat_training, y_hat_testing = [] ,[]
model.eval()
with torch.no_grad():
  for y_storage, dataloader in zip([y_hat_training, y_hat_testing], [train_dataloader, test_dataloader]):
    for batch_c1, batch_c2 in dataloader:
      #print(batch_c1,batch_c2)
      X1 = batch_c1
      X2 = batch_c2
      X1, X2 = X1.to(device), X2.to(device)
      y_hat = model(X1, X2).cpu().numpy().tolist()
      y_storage.extend(y_hat)
# Out:
# DataBatch(x=[322, 23], edge_index=[2, 540], edge_attr=[540, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[322], ptr=[33]) DataBatch(x=[174, 23], edge_index=[2, 328], edge_attr=[328, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[174], ptr=[33])
# DataBatch(x=[662, 23], edge_index=[2, 1196], edge_attr=[1196, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[662], ptr=[33]) DataBatch(x=[254, 23], edge_index=[2, 472], edge_attr=[472, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[254], ptr=[33])
# DataBatch(x=[542, 23], edge_index=[2, 956], edge_attr=[956, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[542], ptr=[33]) DataBatch(x=[216, 23], edge_index=[2, 368], edge_attr=[368, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[216], ptr=[33])
# DataBatch(x=[835, 23], edge_index=[2, 1542], edge_attr=[1542, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[835], ptr=[33]) DataBatch(x=[307, 23], edge_index=[2, 572], edge_attr=[572, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[307], ptr=[33])
# DataBatch(x=[318, 23], edge_index=[2, 522], edge_attr=[522, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[318], ptr=[33]) DataBatch(x=[171, 23], edge_index=[2, 312], edge_attr=[312, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[171], ptr=[33])
# DataBatch(x=[496, 23], edge_index=[2, 864], edge_attr=[864, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[496], ptr=[33]) DataBatch(x=[172, 23], edge_index=[2, 280], edge_attr=[280, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[172], ptr=[33])
# DataBatch(x=[284, 23], edge_index=[2, 440], edge_attr=[440, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[284], ptr=[33]) DataBatch(x=[192, 23], edge_index=[2, 320], edge_attr=[320, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[192], ptr=[33])
# DataBatch(x=[229, 23], edge_index=[2, 330], edge_attr=[330, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[229], ptr=[33]) DataBatch(x=[172, 23], edge_index=[2, 280], edge_attr=[280, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[172], ptr=[33])
# DataBatch(x=[680, 23], edge_index=[2, 1232], edge_attr=[1232, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[680], ptr=[33]) DataBatch(x=[352, 23], edge_index=[2, 640], edge_attr=[640, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[352], ptr=[33])
# DataBatch(x=[581, 23], edge_index=[2, 1034], edge_attr=[1034, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[581], ptr=[33]) DataBatch(x=[271, 23], edge_index=[2, 478], edge_attr=[478, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[271], ptr=[33])
# DataBatch(x=[339, 23], edge_index=[2, 584], edge_attr=[584, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[339], ptr=[33]) DataBatch(x=[242, 23], edge_index=[2, 444], edge_attr=[444, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[242], ptr=[33])
# DataBatch(x=[259, 23], edge_index=[2, 394], edge_attr=[394, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[259], ptr=[33]) DataBatch(x=[201, 23], edge_index=[2, 358], edge_attr=[358, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[201], ptr=[33])
# DataBatch(x=[256, 23], edge_index=[2, 384], edge_attr=[384, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[256], ptr=[33]) DataBatch(x=[241, 23], edge_index=[2, 456], edge_attr=[456, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[241], ptr=[33])
# DataBatch(x=[374, 23], edge_index=[2, 668], edge_attr=[668, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[374], ptr=[33]) DataBatch(x=[236, 23], edge_index=[2, 408], edge_attr=[408, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[236], ptr=[33])
# DataBatch(x=[256, 23], edge_index=[2, 384], edge_attr=[384, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[256], ptr=[33]) DataBatch(x=[184, 23], edge_index=[2, 304], edge_attr=[304, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[184], ptr=[33])
# DataBatch(x=[387, 23], edge_index=[2, 646], edge_attr=[646, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[387], ptr=[33]) DataBatch(x=[194, 23], edge_index=[2, 372], edge_attr=[372, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[194], ptr=[33])
# DataBatch(x=[276, 23], edge_index=[2, 424], edge_attr=[424, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[276], ptr=[33]) DataBatch(x=[288, 23], edge_index=[2, 576], edge_attr=[576, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[288], ptr=[33])
# DataBatch(x=[337, 23], edge_index=[2, 546], edge_attr=[546, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[337], ptr=[33]) DataBatch(x=[256, 23], edge_index=[2, 448], edge_attr=[448, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[256], ptr=[33])
# DataBatch(x=[424, 23], edge_index=[2, 720], edge_attr=[720, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[424], ptr=[33]) DataBatch(x=[256, 23], edge_index=[2, 448], edge_attr=[448, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[256], ptr=[33])
# DataBatch(x=[548, 23], edge_index=[2, 968], edge_attr=[968, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[548], ptr=[33]) DataBatch(x=[253, 23], edge_index=[2, 448], edge_attr=[448, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[253], ptr=[33])
# DataBatch(x=[256, 23], edge_index=[2, 440], edge_attr=[440, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[256], ptr=[33]) DataBatch(x=[168, 23], edge_index=[2, 272], edge_attr=[272, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[168], ptr=[33])
# DataBatch(x=[256, 23], edge_index=[2, 384], edge_attr=[384, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[256], ptr=[33]) DataBatch(x=[235, 23], edge_index=[2, 430], edge_attr=[430, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[235], ptr=[33])
# DataBatch(x=[364, 23], edge_index=[2, 648], edge_attr=[648, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[364], ptr=[33]) DataBatch(x=[212, 23], edge_index=[2, 374], edge_attr=[374, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[212], ptr=[33])
# DataBatch(x=[314, 23], edge_index=[2, 524], edge_attr=[524, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[314], ptr=[33]) DataBatch(x=[187, 23], edge_index=[2, 310], edge_attr=[310, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[187], ptr=[33])
# DataBatch(x=[256, 23], edge_index=[2, 414], edge_attr=[414, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[256], ptr=[33]) DataBatch(x=[199, 23], edge_index=[2, 334], edge_attr=[334, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[199], ptr=[33])
# DataBatch(x=[336, 23], edge_index=[2, 544], edge_attr=[544, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[336], ptr=[33]) DataBatch(x=[231, 23], edge_index=[2, 420], edge_attr=[420, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[231], ptr=[33])
# DataBatch(x=[283, 23], edge_index=[2, 438], edge_attr=[438, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[283], ptr=[33]) DataBatch(x=[286, 23], edge_index=[2, 572], edge_attr=[572, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[286], ptr=[33])
# DataBatch(x=[646, 23], edge_index=[2, 1248], edge_attr=[1248, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[646], ptr=[33]) DataBatch(x=[239, 23], edge_index=[2, 442], edge_attr=[442, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[239], ptr=[33])
# DataBatch(x=[364, 23], edge_index=[2, 626], edge_attr=[626, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[364], ptr=[33]) DataBatch(x=[216, 23], edge_index=[2, 370], edge_attr=[370, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[216], ptr=[33])
# DataBatch(x=[244, 23], edge_index=[2, 360], edge_attr=[360, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[244], ptr=[33]) DataBatch(x=[288, 23], edge_index=[2, 576], edge_attr=[576, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[288], ptr=[33])
# DataBatch(x=[280, 23], edge_index=[2, 432], edge_attr=[432, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[280], ptr=[33]) DataBatch(x=[251, 23], edge_index=[2, 480], edge_attr=[480, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[251], ptr=[33])
# DataBatch(x=[306, 23], edge_index=[2, 534], edge_attr=[534, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[306], ptr=[33]) DataBatch(x=[206, 23], edge_index=[2, 348], edge_attr=[348, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[206], ptr=[33])
# DataBatch(x=[569, 23], edge_index=[2, 1088], edge_attr=[1088, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[569], ptr=[33]) DataBatch(x=[180, 23], edge_index=[2, 318], edge_attr=[318, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[180], ptr=[33])
# DataBatch(x=[457, 23], edge_index=[2, 888], edge_attr=[888, 6], y=[29], Temp=[29], P=[29], mol_x=[29], ap=[29], bp=[29], topopsa=[29], hb=[29], inter_hb=[29], batch=[457], ptr=[30]) DataBatch(x=[199, 23], edge_index=[2, 340], edge_attr=[340, 6], y=[29], Temp=[29], P=[29], mol_x=[29], ap=[29], bp=[29], topopsa=[29], hb=[29], inter_hb=[29], batch=[199], ptr=[30])
# DataBatch(x=[346, 23], edge_index=[2, 604], edge_attr=[604, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[346], ptr=[33]) DataBatch(x=[198, 23], edge_index=[2, 392], edge_attr=[392, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[198], ptr=[33])
# DataBatch(x=[537, 23], edge_index=[2, 946], edge_attr=[946, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[537], ptr=[33]) DataBatch(x=[215, 23], edge_index=[2, 380], edge_attr=[380, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[215], ptr=[33])
# DataBatch(x=[720, 23], edge_index=[2, 1312], edge_attr=[1312, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[720], ptr=[33]) DataBatch(x=[272, 23], edge_index=[2, 512], edge_attr=[512, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[272], ptr=[33])
# DataBatch(x=[364, 23], edge_index=[2, 624], edge_attr=[624, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[364], ptr=[33]) DataBatch(x=[162, 23], edge_index=[2, 280], edge_attr=[280, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[162], ptr=[33])
# DataBatch(x=[384, 23], edge_index=[2, 640], edge_attr=[640, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[384], ptr=[33]) DataBatch(x=[190, 23], edge_index=[2, 316], edge_attr=[316, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[190], ptr=[33])
# DataBatch(x=[245, 23], edge_index=[2, 362], edge_attr=[362, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[245], ptr=[33]) DataBatch(x=[172, 23], edge_index=[2, 280], edge_attr=[280, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[172], ptr=[33])
# DataBatch(x=[534, 23], edge_index=[2, 940], edge_attr=[940, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[534], ptr=[33]) DataBatch(x=[336, 23], edge_index=[2, 608], edge_attr=[608, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[336], ptr=[33])
# DataBatch(x=[764, 23], edge_index=[2, 1400], edge_attr=[1400, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[764], ptr=[33]) DataBatch(x=[328, 23], edge_index=[2, 592], edge_attr=[592, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[328], ptr=[33])
# DataBatch(x=[484, 23], edge_index=[2, 854], edge_attr=[854, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[484], ptr=[33]) DataBatch(x=[264, 23], edge_index=[2, 472], edge_attr=[472, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[264], ptr=[33])
# DataBatch(x=[296, 23], edge_index=[2, 504], edge_attr=[504, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[296], ptr=[33]) DataBatch(x=[260, 23], edge_index=[2, 490], edge_attr=[490, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[260], ptr=[33])
# DataBatch(x=[282, 23], edge_index=[2, 448], edge_attr=[448, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[282], ptr=[33]) DataBatch(x=[263, 23], edge_index=[2, 480], edge_attr=[480, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[263], ptr=[33])
# DataBatch(x=[305, 23], edge_index=[2, 500], edge_attr=[500, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[305], ptr=[33]) DataBatch(x=[191, 23], edge_index=[2, 318], edge_attr=[318, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[191], ptr=[33])
# DataBatch(x=[387, 23], edge_index=[2, 646], edge_attr=[646, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[387], ptr=[33]) DataBatch(x=[194, 23], edge_index=[2, 366], edge_attr=[366, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[194], ptr=[33])
# DataBatch(x=[269, 23], edge_index=[2, 410], edge_attr=[410, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[269], ptr=[33]) DataBatch(x=[285, 23], edge_index=[2, 564], edge_attr=[564, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[285], ptr=[33])
# DataBatch(x=[344, 23], edge_index=[2, 560], edge_attr=[560, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[344], ptr=[33]) DataBatch(x=[256, 23], edge_index=[2, 448], edge_attr=[448, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[256], ptr=[33])
# DataBatch(x=[544, 23], edge_index=[2, 960], edge_attr=[960, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[544], ptr=[33]) DataBatch(x=[253, 23], edge_index=[2, 448], edge_attr=[448, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[253], ptr=[33])
# DataBatch(x=[276, 23], edge_index=[2, 468], edge_attr=[468, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[276], ptr=[33]) DataBatch(x=[182, 23], edge_index=[2, 302], edge_attr=[302, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[182], ptr=[33])
# DataBatch(x=[256, 23], edge_index=[2, 384], edge_attr=[384, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[256], ptr=[33]) DataBatch(x=[234, 23], edge_index=[2, 448], edge_attr=[448, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[234], ptr=[33])
# DataBatch(x=[387, 23], edge_index=[2, 700], edge_attr=[700, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[387], ptr=[33]) DataBatch(x=[222, 23], edge_index=[2, 384], edge_attr=[384, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[222], ptr=[33])
# DataBatch(x=[256, 23], edge_index=[2, 404], edge_attr=[404, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[256], ptr=[33]) DataBatch(x=[193, 23], edge_index=[2, 322], edge_attr=[322, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[193], ptr=[33])
# DataBatch(x=[346, 23], edge_index=[2, 564], edge_attr=[564, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[346], ptr=[33]) DataBatch(x=[231, 23], edge_index=[2, 420], edge_attr=[420, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[231], ptr=[33])
# DataBatch(x=[393, 23], edge_index=[2, 658], edge_attr=[658, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[393], ptr=[33]) DataBatch(x=[262, 23], edge_index=[2, 516], edge_attr=[516, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[262], ptr=[33])
# DataBatch(x=[641, 23], edge_index=[2, 1244], edge_attr=[1244, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[641], ptr=[33]) DataBatch(x=[239, 23], edge_index=[2, 440], edge_attr=[440, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[239], ptr=[33])
# DataBatch(x=[280, 23], edge_index=[2, 456], edge_attr=[456, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[280], ptr=[33]) DataBatch(x=[228, 23], edge_index=[2, 408], edge_attr=[408, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[228], ptr=[33])
# DataBatch(x=[268, 23], edge_index=[2, 408], edge_attr=[408, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[268], ptr=[33]) DataBatch(x=[272, 23], edge_index=[2, 544], edge_attr=[544, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[272], ptr=[33])
# DataBatch(x=[256, 23], edge_index=[2, 420], edge_attr=[420, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[256], ptr=[33]) DataBatch(x=[209, 23], edge_index=[2, 360], edge_attr=[360, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[209], ptr=[33])
# DataBatch(x=[486, 23], edge_index=[2, 908], edge_attr=[908, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[486], ptr=[33]) DataBatch(x=[188, 23], edge_index=[2, 326], edge_attr=[326, 6], y=[32], Temp=[32], P=[32], mol_x=[32], ap=[32], bp=[32], topopsa=[32], hb=[32], inter_hb=[32], batch=[188], ptr=[33])
# DataBatch(x=[425, 23], edge_index=[2, 832], edge_attr=[832, 6], y=[24], Temp=[24], P=[24], mol_x=[24], ap=[24], bp=[24], topopsa=[24], hb=[24], inter_hb=[24], batch=[425], ptr=[25]) DataBatch(x=[179, 23], edge_index=[2, 310], edge_attr=[310, 6], y=[24], Temp=[24], P=[24], mol_x=[24], ap=[24], bp=[24], topopsa=[24], hb=[24], inter_hb=[24], batch=[179], ptr=[25])

# %%
parity_plots( y_train, y_hat_training, y_test, y_hat_testing)

# %%
model = GHGNN(n_atom_features(), n_bond_features(), 3, 25, 4).to(device)
checkpoint = torch.load('GNN_MG_sol.pth')
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
m_p = model.parameters()  #list(model.parameters())
print( model.mlp1.parameters() , model.mlp2.parameters() ) 
model_param =  [model.mlp1.parameters() , model.mlp2.parameters() ]
optimizer_1 = torch.optim.Adam(model.mlp1.parameters(), lr = 0.0006031500598155615)
optimizer_2 = torch.optim.Adam(model.mlp2.parameters(), lr = 0.0006031500598155615)
optimizer_3 = torch.optim.Adam(model.mlp3.parameters(), lr = 0.0006031500598155615)
# Out:
# <generator object Module.parameters at 0x00000165E49298C0> <generator object Module.parameters at 0x00000165E492BAE0>

# %%
g1s = [train_df['g_hba'].iloc[0]]  #train_df['g_hba'].tolist()
g2s = [train_df['g_hbd'].iloc[0]]  #train_df['g_hbd'].tolist()
pair_dataset = PairDataset(g1s, g2s)
print(pair_dataset)
data_loader_test  = torch.utils.data.DataLoader(pair_dataset,  batch_size=1, shuffle=False, drop_last=False, collate_fn=collate) 
print(data_loader_test)
# Out:
# <__main__.PairDataset object at 0x00000165E49EF150>
# <torch.utils.data.dataloader.DataLoader object at 0x00000165E4D0D190>

# %%
model.eval()
with torch.no_grad():
    for batch_x1, batch_x2 in data_loader_test:
        print( model(batch_x1, batch_x2 ).item() )
# Out:
# -5.318721294403076
